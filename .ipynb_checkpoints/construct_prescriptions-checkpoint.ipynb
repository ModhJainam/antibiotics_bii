# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
from pathlib import Path

# %%
#import file paths from directory
datadir = Path("/project/biocomplexity/MeaslesProject/APCDdata/RX")
datafiles = list(datadir.iterdir())
len(datafiles)
# Out:
# 8

# %%
df = pd.read_csv(datafiles[0], sep = "|", nrows=10000)
cats = list(df.select_dtypes(include = ['object']).columns)
nums = list(df.select_dtypes(include = ['int64', 'float64']).columns)

# %%
df.loc[:,  ['Billing Provider Specialty',
 'Billing Provider ZIP',
 'Billing Provider County',
 'Billing Provider State',
 'Billing Provider MSA',
 'Service Provider Specialty',
 'Service Provider ZIP',
 'Service Provider County',
 'Service Provider State',
 'Service Provider MSA',
 'Attrib PCP Specialty',
 'Attrib PCP ZIP',
 'Attrib PCP County',
 'Attrib PCP State',
 'Attrib PCP MSA']]
# Out:
#      Billing Provider Specialty Billing Provider ZIP Billing Provider County  \
# 0                      Pharmacy                23233                 HENRICO
# 1                      Pharmacy                23456     VIRGINIA BEACH CITY
# 2                      Pharmacy                37660                SULLIVAN
# 3                      Pharmacy                45069                  BUTLER
# 4                      Pharmacy                24266                 RUSSELL
# ...                         ...                  ...                     ...
# 9995                   Pharmacy                22031                 FAIRFAX
# 9996                   Pharmacy                23418                ACCOMACK
# 9997                   Pharmacy                22603               FREDERICK
# 9998                   Pharmacy                22180                 FAIRFAX
# 9999                   Pharmacy                23322         CHESAPEAKE CITY
#
# ...

# %%
list(df.columns)
# Out:
# ['Incurred Date',
#  'Claim ID',
#  'MI Person Key',
#  'Payer LOB',
#  'Payer Type',
#  'Claim Status',
#  'Primary Insurance Flag',
#  'Member Zip Code DOS',
#  'Member County DOS',
#  'Member Age DOS',
#  'Member Age Band DOS',
#  'Health Planning Region',
#  'Health Planning District',
#  'ADULT_FLAG',
#  'Member Gender',
#  'Member Race',
#  'Hispanic Indicator',
#  'HCG Setting',
#  'HCG Line',
#  'HCG Detail',
#  'Therapeutic Class 1',
#  'Therapeutic Class 2',
#  'Therapeutic Class 3',
#  'NDC',
#  'Drug Code',
#  'Drug Name',
#  'GPI',
#  'GPI Generic Name',
#  'Brand Status',
#  'Manufacturer',
#  'Strength',
#  'Unit',
#  'Dosage Form',
#  'RX Fill Source',
#  'Primary Substitution Drug Code',
#  'Primary Substitution Drug Name',
#  'Primary Substitution Brand Status',
#  'Primary Substitution Manufacturer',
#  'Primary Substitution Flag',
#  'Billing Provider Specialty',
#  'Billing Provider ZIP',
#  'Billing Provider County',
#  'Billing Provider State',
# ...

# %%
prescriptions = df.loc[:,['Incurred Date', 'Member Zip Code DOS',
                         'Therapeutic Class 1',
 'Therapeutic Class 2',
 'Therapeutic Class 3',
 'NDC',
 'Drug Code',
 'Drug Name',
 'GPI',
 'GPI Generic Name',
 'Brand Status',
 'Manufacturer',
 'Strength',
 'Unit',
                         'Total Allowed',
 'Total Utilization',
 'Total RX Paid',
 'Total RX Days Supply']]
prescriptions.tail()
# Out:
#       Incurred Date Member Zip Code DOS Therapeutic Class 1  \
# 9995       20180701               22042     ANTIDEPRESSANTS
# 9996       20180701               23301   ANTIHYPERTENSIVES
# 9997       20180701               22601   ANTIHYPERTENSIVES
# 9998       20180701               22180   ANTIHYPERTENSIVES
# 9999       20180701               23322       BETA BLOCKERS
#
#                                   Therapeutic Class 2  \
# 9995  Selective Serotonin Reuptake Inhibitors (SSRIs)
# 9996                 Antiadrenergic Antihypertensives
# 9997                    Antihypertensive Combinations
# 9998              Angiotensin II Receptor Antagonists
# 9999                              Alpha-Beta Blockers
#
#                                   Therapeutic Class 3  \
# 9995  Selective Serotonin Reuptake Inhibitors (SSRIs)
# 9996               Antiadrenergics - Centrally Acting
# 9997          ACE Inhibitors & Thiazide/Thiazide-Like
# ...

# %%
query[[ 'Therapeutic Class 1',
 'Therapeutic Class 2',
 'Therapeutic Class 3',
 'NDC',
 'Drug Name',
 'GPI',
 'GPI Generic Name',
 'Brand Status',
 'Manufacturer',
 'Strength',
 'Unit',
 'Dosage Form',
 'RX Fill Source',
 'Primary Substitution Drug Code',
 'Primary Substitution Drug Name',
 'Primary Substitution Brand Status',
 'Primary Substitution Manufacturer',
 'Primary Substitution Flag']]
# Out:
#      Therapeutic Class 1    Therapeutic Class 2    Therapeutic Class 3  \
# 547      DERMATOLOGICALS  Antibiotics - Topical  Antibiotics - Topical
# 1268     DERMATOLOGICALS  Antibiotics - Topical  Antibiotics - Topical
# 1458     DERMATOLOGICALS  Antibiotics - Topical  Antibiotics - Topical
# 1764     DERMATOLOGICALS  Antibiotics - Topical  Antibiotics - Topical
# 2857     DERMATOLOGICALS  Antibiotics - Topical  Antibiotics - Topical
# 2876     DERMATOLOGICALS  Antibiotics - Topical  Antibiotics - Topical
# 3111     DERMATOLOGICALS  Antibiotics - Topical  Antibiotics - Topical
# 3134     DERMATOLOGICALS  Antibiotics - Topical  Antibiotics - Topical
# 3564     DERMATOLOGICALS  Antibiotics - Topical  Antibiotics - Topical
# 3682     DERMATOLOGICALS  Antibiotics - Topical  Antibiotics - Topical
# 3866     DERMATOLOGICALS  Antibiotics - Topical  Antibiotics - Topical
# 4771     DERMATOLOGICALS  Antibiotics - Topical  Antibiotics - Topical
# ...
