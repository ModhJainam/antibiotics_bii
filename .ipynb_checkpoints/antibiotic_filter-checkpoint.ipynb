# %%
import pandas as pd
import numpy as np

# %%
ndcfile = "/scratch/jhm3ab/antibiotic_bii/ndclist/product.txt"
abfile = "/scratch/jhm3ab/antibiotic_bii/USC5_DrugClass.csv"
ndc = pd.read_csv(ndcfile, sep = '\t', encoding='unicode_escape')
ab = pd.read_csv(abfile, index_col=0)

# %%
joined = pd.merge(ndc, ab, how = 'right', left_on = ndc['NONPROPRIETARYNAME'].str.lower(), right_on=ab['drug'].str.lower())

# %%
unknown = joined.loc[joined['NONPROPRIETARYNAME'].isna()]
known = joined.loc[~joined['NONPROPRIETARYNAME'].isna()]

# %%
udrugs = unknown['key_0'].unique().tolist()
kdrugs = known['key_0'].unique().tolist()

# %%
ab_unknown = ab.loc[ab['drug'].str.lower().isin(udrugs)]

# %%
ab
# Out:
#                    usc5  usc5_num    productname            drug  \
# 0       AMINOGLYCOSIDES     15170  AMIKACIN SULF        Amikacin
# 1       AMINOGLYCOSIDES     15170         AMIKIN        Amikacin
# 2       AMINOGLYCOSIDES     15170       ARIKAYCE        Amikacin
# 3       AMINOGLYCOSIDES     15170        BETHKIS      Tobramycin
# 4       AMINOGLYCOSIDES     15170      GARAMYCIN      Gentamycin
# ..                  ...       ...            ...             ...
# 344  TETRACYC/ANTIFUNGL     15113    MYSTECLIN F  Amphotericin B
# 345  TRIMETHOPRIM,PLAIN     15320        PRIMSOL    Trimethoprim
# 346  TRIMETHOPRIM,PLAIN     15320      PROLOPRIM    Trimethoprim
# 347  TRIMETHOPRIM,PLAIN     15320   TRIMETHOPRIM    Trimethoprim
# 348  TRIMETHOPRIM,PLAIN     15320        TRIMPEX    Trimethoprim
#
#                              class
# 0                  Aminoglycosides
# 1                  Aminoglycosides
# 2                  Aminoglycosides
# 3                  Aminoglycosides
# 4                  Aminoglycosides
# ..                             ...
# 344                  Tetracyclines
# 345  Trimethoprim and combinations
# 346  Trimethoprim and combinations
# 347  Trimethoprim and combinations
# 348  Trimethoprim and combinations
#
# [349 rows x 5 columns]

# %%
len(kdrugs)
# Out:
# 63

# %%
len(ab['drug'].unique().tolist())
# Out:
# 116

# %%
classes = ab['class'].unique().tolist()
len(classes)
# Out:
# 17

# %%
classes = ['Aminoglycoside', 
           'Penicillin',
 'Polymyxin',
 'Lipopeptide',
 'Glycopeptide',
 'Carbapenem',
 'Cephalosporin',
 'Monobactam',
 'Trimethoprim',
 'Chloramphenicol',
 'Macrolide',
 'Oxazolidinone',
 'Quinolone',
 'Tetracycline',
 'Glycylcycline']
# Out:
# ['Aminoglycosides',
#  'Broad-spectrum Penicillins',
#  'Narrow-spectrum Penicillins',
#  'Others',
#  'Polymyxins',
#  'Lipopeptides',
#  'Glycopeptides',
#  'Carbapenems',
#  'Cephalosporins',
#  'Monobactams',
#  'Trimethoprim and combinations',
#  'Chloramphenicols',
#  'Macrolides',
#  'Oxazolidinones',
#  'Quinolones',
#  'Tetracyclines',
#  'Glycylcyclines']

# %%
pharm=ndc['PHARM_CLASSES'].unique().tolist()

# %%
search = []
failed = []
for c in classes:
    found = False
    for p in pharm:
        p = str(p)
        if c.lower() in p.lower():
            search.append(p)
            found = True
    if not found:
        failed.append(c)

# %%
failed
# Out:
# ['Broad-spectrum Penicillins',
#  'Narrow-spectrum Penicillins',
#  'Others',
#  'Trimethoprim and combinations',
#  'Chloramphenicols',
#  'Glycylcyclines']

# %%
filtered = ndc[ndc['PHARM_CLASSES'].isin(search)]

# %%
filtered
# Out:
#                                              PRODUCTID PRODUCTNDC  \
# 128     0003-2560_e44ad54c-6b64-4505-af49-1810176c0114  0003-2560
# 129     0003-2570_e44ad54c-6b64-4505-af49-1810176c0114  0003-2570
# 203     0006-3516_314c9ca7-26c9-4aae-bd43-805fc724887e  0006-3516
# 206     0006-3822_38feba4f-a86c-4d3f-9a01-0cef84c46680  0006-3822
# 207     0006-3823_38feba4f-a86c-4d3f-9a01-0cef84c46680  0006-3823
# ...                                                ...        ...
# 115682  99207-463_a594be33-33ce-4304-a6fe-65a4eeda3f19  99207-463
# 115683  99207-464_a594be33-33ce-4304-a6fe-65a4eeda3f19  99207-464
# 115684  99207-465_a594be33-33ce-4304-a6fe-65a4eeda3f19  99207-465
# 115685  99207-466_a594be33-33ce-4304-a6fe-65a4eeda3f19  99207-466
# 115686  99207-467_a594be33-33ce-4304-a6fe-65a4eeda3f19  99207-467
#
#                 PRODUCTTYPENAME PROPRIETARYNAME PROPRIETARYNAMESUFFIX  \
# 128     HUMAN PRESCRIPTION DRUG         AZACTAM                   NaN
# 129     HUMAN PRESCRIPTION DRUG         AZACTAM                   NaN
# 203     HUMAN PRESCRIPTION DRUG        PRIMAXIN                    IV
# 206     HUMAN PRESCRIPTION DRUG        CANCIDAS                   NaN
# 207     HUMAN PRESCRIPTION DRUG        CANCIDAS                   NaN
# ...                         ...             ...                   ...
# 115682  HUMAN PRESCRIPTION DRUG         Solodyn                   NaN
# 115683  HUMAN PRESCRIPTION DRUG         Solodyn                   NaN
# 115684  HUMAN PRESCRIPTION DRUG         Solodyn                   NaN
# 115685  HUMAN PRESCRIPTION DRUG         Solodyn                   NaN
# 115686  HUMAN PRESCRIPTION DRUG         Solodyn                   NaN
#
#                     NONPROPRIETARYNAME  \
# 128                          AZTREONAM
# 129                          AZTREONAM
# 203     imipenem and cilastatin sodium
# 206                CASPOFUNGIN ACETATE
# 207                CASPOFUNGIN ACETATE
# ...                                ...
# 115682       minocycline hydrochloride
# 115683       minocycline hydrochloride
# 115684       minocycline hydrochloride
# 115685       minocycline hydrochloride
# 115686       minocycline hydrochloride
#
#                                       DOSAGEFORMNAME  \
# 128                  INJECTION, POWDER, FOR SOLUTION
# 129                  INJECTION, POWDER, FOR SOLUTION
# 203                  INJECTION, POWDER, FOR SOLUTION
# 206     INJECTION, POWDER, LYOPHILIZED, FOR SOLUTION
# 207     INJECTION, POWDER, LYOPHILIZED, FOR SOLUTION
# ...                                              ...
# 115682         TABLET, FILM COATED, EXTENDED RELEASE
# 115683         TABLET, FILM COATED, EXTENDED RELEASE
# 115684         TABLET, FILM COATED, EXTENDED RELEASE
# 115685         TABLET, FILM COATED, EXTENDED RELEASE
# 115686         TABLET, FILM COATED, EXTENDED RELEASE
#
#                          ROUTENAME  STARTMARKETINGDATE  ENDMARKETINGDATE  \
# 128     INTRAMUSCULAR; INTRAVENOUS            20100401               NaN
# 129     INTRAMUSCULAR; INTRAVENOUS            20100401               NaN
# 203                    INTRAVENOUS            19851126               NaN
# 206                    INTRAVENOUS            20010126               NaN
# 207                    INTRAVENOUS            20010126               NaN
# ...                            ...                 ...               ...
# 115682                        ORAL            20090723               NaN
# 115683                        ORAL            20090723               NaN
# 115684                        ORAL            20100927               NaN
# 115685                        ORAL            20100927               NaN
# 115686                        ORAL            20100927               NaN
#
#        MARKETINGCATEGORYNAME APPLICATIONNUMBER                 LABELERNAME  \
# 128                      NDA         NDA050580  E.R. Squibb & Sons, L.L.C.
# 129                      NDA         NDA050580  E.R. Squibb & Sons, L.L.C.
# 203                      NDA         NDA050587     Merck Sharp & Dohme LLC
# 206                      NDA         NDA021227     Merck Sharp & Dohme LLC
# 207                      NDA         NDA021227     Merck Sharp & Dohme LLC
# ...                      ...               ...                         ...
# 115682                   NDA         NDA050808        Bausch Health US LLC
# 115683                   NDA         NDA050808        Bausch Health US LLC
# 115684                   NDA         NDA050808        Bausch Health US LLC
# 115685                   NDA         NDA050808        Bausch Health US LLC
# 115686                   NDA         NDA050808        Bausch Health US LLC
#
#                       SUBSTANCENAME ACTIVE_NUMERATOR_STRENGTH  \
# 128                       AZTREONAM                         1
# 129                       AZTREONAM                         2
# 203     CILASTATIN SODIUM; IMIPENEM                  500; 500
# 206             CASPOFUNGIN ACETATE                         5
# 207             CASPOFUNGIN ACETATE                         7
# ...                             ...                       ...
# 115682    MINOCYCLINE HYDROCHLORIDE                        65
# 115683    MINOCYCLINE HYDROCHLORIDE                       115
# 115684    MINOCYCLINE HYDROCHLORIDE                        55
# 115685    MINOCYCLINE HYDROCHLORIDE                        80
# 115686    MINOCYCLINE HYDROCHLORIDE                       105
#
#         ACTIVE_INGRED_UNIT                                      PHARM_CLASSES  \
# 128                    g/1   Monobactam Antibacterial [EPC], Monobactams [CS]
# 129                    g/1   Monobactam Antibacterial [EPC], Monobactams [CS]
# 203     mg/100mL; mg/100mL  Carbapenems [CS], Dipeptidase Inhibitors [MoA]...
# 206                  mg/mL   Echinocandin Antifungal [EPC], Lipopeptides [CS]
# 207                  mg/mL   Echinocandin Antifungal [EPC], Lipopeptides [CS]
# ...                    ...                                                ...
# 115682                mg/1  Tetracycline-class Drug [EPC], Tetracyclines [CS]
# 115683                mg/1  Tetracycline-class Drug [EPC], Tetracyclines [CS]
# 115684                mg/1  Tetracycline-class Drug [EPC], Tetracyclines [CS]
# 115685                mg/1  Tetracycline-class Drug [EPC], Tetracyclines [CS]
# 115686                mg/1  Tetracycline-class Drug [EPC], Tetracyclines [CS]
#
#        DEASCHEDULE NDC_EXCLUDE_FLAG  LISTING_RECORD_CERTIFIED_THROUGH
# 128            NaN                N                        20221231.0
# 129            NaN                N                        20221231.0
# 203            NaN                N                        20231231.0
# 206            NaN                N                        20231231.0
# 207            NaN                N                        20231231.0
# ...            ...              ...                               ...
# 115682         NaN                N                        20221231.0
# 115683         NaN                N                        20221231.0
# 115684         NaN                N                        20221231.0
# 115685         NaN                N                        20221231.0
# 115686         NaN                N                        20221231.0
#
# [2866 rows x 20 columns]
